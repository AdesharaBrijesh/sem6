# %%
"""1. key 8
HelloWelcomeToUVPCE

2. key 23
Thisiscaesercipheralgorithm

3. key 17
CaeserCipherisWeakAlgorithm

4. key 13
YouAreSmarttoAttackCaeserCipher
"""


key=1
msg=input("enter encrypted message")
msglist=list(msg)
l2=[]
k=1

def dec(msga,k):
    for d in msga:
            x=0
            m=int(ord(d))
            if d.isupper():
                x=65
            else: 
                x=97
            
            j=chr((m-k-x)%26+x)
            print(j,end="")

while(k<25):
    print("\nkey is= ",k)
    dec(msglist,k)
    k=k+1
# Out:
# enter encrypted messageTrvjviTzgyvizjNvrbRcxfizkyd
#
# key is=  1
# SquiuhSyfxuhyiMuqaQbwehyjxc
# key is=  2
# RpthtgRxewtgxhLtpzPavdgxiwb
# key is=  3
# QosgsfQwdvsfwgKsoyOzucfwhva
# key is=  4
# PnrfrePvcurevfJrnxNytbevguz
# key is=  5
# OmqeqdOubtqdueIqmwMxsadufty
# key is=  6
# NlpdpcNtaspctdHplvLwrzctesx
# key is=  7
# MkocobMszrobscGokuKvqybsdrw
# key is=  8
# LjnbnaLryqnarbFnjtJupxarcqv
# key is=  9
# KimamzKqxpmzqaEmisItowzqbpu
# key is=  10
# JhlzlyJpwolypzDlhrHsnvypaot
# key is=  11
# IgkykxIovnkxoyCkgqGrmuxozns
# key is=  12
# HfjxjwHnumjwnxBjfpFqltwnymr
# key is=  13
# GeiwivGmtlivmwAieoEpksvmxlq
# key is=  14
# FdhvhuFlskhulvZhdnDojrulwkp
# key is=  15
# EcgugtEkrjgtkuYgcmCniqtkvjo
# key is=  16
# DbftfsDjqifsjtXfblBmhpsjuin
# key is=  17
# CaeserCipherisWeakAlgorithm
# key is=  18
# BzdrdqBhogdqhrVdzjZkfnqhsgl
# key is=  19
# AycqcpAgnfcpgqUcyiYjempgrfk
# key is=  20
# ZxbpboZfmebofpTbxhXidlofqej
# key is=  21
# YwaoanYeldaneoSawgWhcknepdi
# key is=  22
# XvznzmXdkczmdnRzvfVgbjmdoch
# key is=  23
# WuymylWcjbylcmQyueUfailcnbg
# key is=  24
# VtxlxkVbiaxkblPxtdTezhkbmaf
